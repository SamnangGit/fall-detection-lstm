# %%
# Force reinstall numpy and PyTorch/Torchvision to resolve potential conflicts
# !pip uninstall numpy torch torchvision torchaudio -y
# !pip install --no-cache-dir -I numpy torch torchvision torchaudio

# -*- coding: utf-8 -*-
"""
Fall Detection using Mediapipe and RNN in Google Colab (Revised Paths).ipynb

Automatically generated by Colaboratory.

Adapts to train_data / test_data structure.
"""

# ==============================================================================
# Cell 1: Setup Environment - Mount Drive & Install Libraries
# ==============================================================================
import os
import sys
import subprocess
from google.colab import drive

# Mount Google Drive
print("Mounting Google Drive...")
drive.mount('/content/drive')
print("Google Drive mounted successfully.")

# Install necessary libraries
print("Installing libraries...")
try:
    import mediapipe
    import torch
    import torchvision
    import torchaudio
    print("Libraries already installed or installation not needed in this environment.")
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "mediapipe", "torch", "torchvision", "torchaudio", "opencv-python"])
    print("Libraries installed successfully.")

# Import remaining libraries
import cv2
import numpy as np
import mediapipe as mp
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# from sklearn.model_selection import train_test_split # No longer needed for this structure
import time
import pickle 
import glob # For finding files

print("All necessary libraries are imported.")

# ==============================================================================
# Cell 2: Configuration - Define Paths and Hyperparameters
# ==============================================================================

# --- User Defined Paths ---
BASE_DRIVE_PATH = '/content/drive/MyDrive/dataset' # Main folder 

TRAIN_DATA_DIR = os.path.join(BASE_DRIVE_PATH, 'train_data')
TEST_DATA_DIR = os.path.join(BASE_DRIVE_PATH, 'test_data')

CLASS_FOLDERS = ["backward_fall", "forward_fall", "side_fall", "non_fall"]

FEATURES_OUTPUT_DIR = os.path.join(BASE_DRIVE_PATH, 'processed_features') # Combined features folder
MODEL_SAVE_DIR = os.path.join(BASE_DRIVE_PATH, 'trained_models')
MODEL_NAME = 'fall_detection_rnn_v2.pth' 

# --- Preprocessing Settings ---
FRAME_SKIP = 3  
SEQUENCE_LENGTH = 30 

# --- Model & Training Hyperparameters ---
NUM_CLASSES = len(CLASS_FOLDERS)
INPUT_SIZE = 33 * 3  # 33 landmarks * 3 coordinates (x, y, visibility)
HIDDEN_SIZE = 128
NUM_LAYERS = 2
BATCH_SIZE = 32
LEARNING_RATE = 0.001
NUM_EPOCHS = 50
# VALIDATION_SPLIT = 0.2 # Removed - Using dedicated test_data folder for validation/testing

# --- Device Configuration ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# --- Create output directories if they don't exist ---
os.makedirs(FEATURES_OUTPUT_DIR, exist_ok=True)
# Create class subdirectories within features directory if they don't exist
for class_name in CLASS_FOLDERS:
    os.makedirs(os.path.join(FEATURES_OUTPUT_DIR, class_name), exist_ok=True)
os.makedirs(MODEL_SAVE_DIR, exist_ok=True)

# --- Define class to index mapping ---
label_map = {name: i for i, name in enumerate(CLASS_FOLDERS)}
index_to_name = {i: name for name, i in label_map.items()}

print("Configuration loaded:")
print(f"  Base Path: {BASE_DRIVE_PATH}")
print(f"  Train Data Path: {TRAIN_DATA_DIR}")
print(f"  Test Data Path: {TEST_DATA_DIR}")
print(f"  Feature Path: {FEATURES_OUTPUT_DIR}")
print(f"  Model Save Path: {MODEL_SAVE_DIR}")
print(f"  Classes: {CLASS_FOLDERS}")
print(f"  Label Map: {label_map}")
print(f"  Frame Skip: {FRAME_SKIP}")
print(f"  Sequence Length: {SEQUENCE_LENGTH}")


# ==============================================================================
# Cell 3: Data Loading & Preprocessing - Frame & Feature Extraction
# ==============================================================================

# Initialize Mediapipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, # Process video stream
                    model_complexity=1,      
                    smooth_landmarks=True,
                    enable_segmentation=False,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5)

mp_drawing = mp.solutions.drawing_utils 

def extract_keypoints_from_video(video_path, frame_skip, sequence_length):
    """
    Extracts Mediapipe keypoints from a video file. Handles sequence padding/truncation.
    (Same function as before)
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return None

    frame_count = 0
    keypoints_sequence = []

    while cap.isOpened():
        success, frame = cap.read()
        if not success: break 

        if frame_count % frame_skip == 0:
            try:
                image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                image_rgb.flags.writeable = False
                results = pose.process(image_rgb)
                if results.pose_landmarks:
                    frame_keypoints = []
                    for landmark in results.pose_landmarks.landmark:
                        frame_keypoints.extend([landmark.x, landmark.y, landmark.visibility])
                    keypoints_sequence.append(frame_keypoints)
                else:
                    keypoints_sequence.append(np.zeros(INPUT_SIZE).tolist()) # Pad with zeros if no pose
            except Exception as e:
                print(f"Error processing frame {frame_count} in {video_path}: {e}")
                keypoints_sequence.append(np.zeros(INPUT_SIZE).tolist())

        frame_count += 1
    cap.release()

    num_extracted_frames = len(keypoints_sequence)
    if num_extracted_frames == 0:
        print(f"Warning: No keypoints extracted from {video_path}")
        return None

    final_sequence = np.zeros((sequence_length, INPUT_SIZE), dtype=np.float32)
    if num_extracted_frames >= sequence_length:
        final_sequence = np.array(keypoints_sequence[:sequence_length])
    else:
        sequence_array = np.array(keypoints_sequence)
        final_sequence[:num_extracted_frames] = sequence_array


    return final_sequence


def process_data_folder(data_directory, class_folders, label_map, feature_output_dir):
    """Processes videos in a given directory (train or test) and saves features."""
    all_feature_files = []
    all_labels = []
    print(f"\nProcessing data source: {data_directory}")

    for class_name in class_folders:
        class_label = label_map[class_name]
        video_folder_abs = os.path.join(data_directory, class_name)
        # Features are saved in a common structure under FEATURES_OUTPUT_DIR
        feature_class_dir = os.path.join(feature_output_dir, class_name)

        print(f"\n  Processing class: {class_name} (Label: {class_label})")
        print(f"    Video folder: {video_folder_abs}")

        video_files = glob.glob(os.path.join(video_folder_abs, '*.mp4')) + \
                      glob.glob(os.path.join(video_folder_abs, '*.avi')) # Add other extensions

        if not video_files:
            print(f"    Warning: No video files found in {video_folder_abs}")
            continue

        for video_path in video_files:
            video_filename = os.path.basename(video_path)
            feature_filename = os.path.splitext(video_filename)[0] + '.pkl'
            feature_save_path = os.path.join(feature_class_dir, feature_filename)

            if os.path.exists(feature_save_path):
                print(f"    Skipping {video_filename}, features already exist at {feature_save_path}")
                all_feature_files.append(feature_save_path)
                all_labels.append(class_label)
                continue

            print(f"    Processing {video_filename}...")
            keypoints_data = extract_keypoints_from_video(video_path, FRAME_SKIP, SEQUENCE_LENGTH)

            if keypoints_data is not None:
                try:
                    with open(feature_save_path, 'wb') as f:
                        pickle.dump(keypoints_data, f)
                    all_feature_files.append(feature_save_path)
                    all_labels.append(class_label)
                    print(f"      Saved features to {feature_save_path}")
                except Exception as e:
                    print(f"      Error saving features for {video_filename}: {e}")
            else:
                print(f"      Failed to extract features for {video_filename}.")

    return all_feature_files, all_labels


# --- Main Preprocessing ---
print("\nStarting Feature Extraction...")
start_time = time.time()

# Process Training Data
train_feature_files, train_labels = process_data_folder(
    TRAIN_DATA_DIR, CLASS_FOLDERS, label_map, FEATURES_OUTPUT_DIR
)

# Process Testing Data
test_feature_files, test_labels = process_data_folder(
    TEST_DATA_DIR, CLASS_FOLDERS, label_map, FEATURES_OUTPUT_DIR
)

end_time = time.time()
print(f"\nFeature extraction completed in {end_time - start_time:.2f} seconds.")
print(f"Total training feature files processed/loaded: {len(train_feature_files)}")
print(f"Total testing feature files processed/loaded: {len(test_feature_files)}")

# Close the pose object when done
pose.close()


# ==============================================================================
# Cell 4: Dataset and DataLoader Preparation
# ==============================================================================

# --- Check if data was loaded ---
if not train_feature_files:
     raise ValueError("No training feature files were processed or found. Check train_data paths and preprocessing steps.")
if not test_feature_files:
     print("Warning: No testing feature files were processed or found. Check test_data paths. Proceeding without test data evaluation during training.")

# --- Define PyTorch Dataset ---
class PoseSequenceDataset(Dataset):
    def __init__(self, feature_paths, labels):
        self.feature_paths = feature_paths
        self.labels = labels

    def __len__(self):
        return len(self.feature_paths)

    def __getitem__(self, idx):
        feature_path = self.feature_paths[idx]
        label = self.labels[idx]
        try:
            with open(feature_path, 'rb') as f:
                sequence_data = pickle.load(f)
            sequence_tensor = torch.tensor(sequence_data, dtype=torch.float32)
            label_tensor = torch.tensor(label, dtype=torch.long)
            return sequence_tensor, label_tensor
        except Exception as e:
            print(f"Error loading or processing file {feature_path}: {e}")
            # Return dummy data matching expected shapes/types
            return torch.zeros((SEQUENCE_LENGTH, INPUT_SIZE), dtype=torch.float32), torch.tensor(0, dtype=torch.long)

# --- Create Datasets and DataLoaders ---
# No train_test_split needed as we have separate folders
train_dataset = PoseSequenceDataset(train_feature_files, train_labels)
test_dataset = PoseSequenceDataset(test_feature_files, test_labels) # Using test data for evaluation

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Use test_loader for evaluation during training (acting as validation)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print("Datasets and DataLoaders created.")
print(f"  Training samples: {len(train_dataset)}")
print(f"  Testing samples: {len(test_dataset)}")


# ==============================================================================
# Cell 5: Model Building (RNN - LSTM/GRU)
# ==============================================================================

class FallDetectionRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, rnn_type='LSTM'):
        super(FallDetectionRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn_type = rnn_type

        rnn_dropout = 0.2 if num_layers > 1 else 0 
        if rnn_type == 'LSTM':
            self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=rnn_dropout)
        elif rnn_type == 'GRU':
            self.rnn = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=rnn_dropout)
        else:
            raise ValueError("Unsupported RNN type. Choose 'LSTM' or 'GRU'.")


        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        if self.rnn_type == 'LSTM':
            c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
            hidden = (h0, c0)
        else: # GRU
            hidden = h0

        out, _ = self.rnn(x, hidden)
        out = self.fc(out[:, -1, :]) # Use output of the last time step
        return out

# --- Instantiate the model ---
model = FallDetectionRNN(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, rnn_type='LSTM') # Or 'GRU'
model.to(DEVICE)

print("Model Architecture:")
print(model)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total trainable parameters: {total_params}")


# ==============================================================================
# Cell 6: Training Setup - Loss Function and Optimizer
# ==============================================================================

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

print("Loss function and optimizer defined.")
print(f"  Criterion: {criterion}")
print(f"  Optimizer: Adam (LR={LEARNING_RATE})")

# ==============================================================================
# Cell 7: Model Training Loop
# ==============================================================================

print("\nStarting Training...")
best_test_accuracy = 0.0 # Saving based on test set performance
model_save_path = os.path.join(MODEL_SAVE_DIR, MODEL_NAME)

for epoch in range(NUM_EPOCHS):
    epoch_start_time = time.time()

    # --- Training Phase ---
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for i, (sequences, labels) in enumerate(train_loader):
        sequences, labels = sequences.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(sequences)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train

    # --- Testing Phase (using the test_data folder) ---
    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    # Check if test_loader is available (in case test data was empty)
    if test_loader:
        with torch.no_grad():
            for sequences, labels in test_loader:
                sequences, labels = sequences.to(DEVICE), labels.to(DEVICE)
                outputs = model(sequences)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        test_loss /= len(test_loader)
        test_accuracy = 100 * correct_test / total_test
    else: # Handle case where there's no test data
        test_loss = 0.0
        test_accuracy = 0.0


    epoch_end_time = time.time()
    epoch_duration = epoch_end_time - epoch_start_time

    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}] ({epoch_duration:.2f}s) | "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}% | "
          f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%") # Changed Val to Test

    # --- Save the best model based on test accuracy ---

    if test_loader and test_accuracy > best_test_accuracy:
        best_test_accuracy = test_accuracy
        torch.save(model.state_dict(), model_save_path)
        print(f"  -> New best model saved to {model_save_path} (Test Acc: {best_test_accuracy:.2f}%)") 

print("\nTraining Finished.")
if test_loader:
    print(f"Best Test Accuracy achieved during training: {best_test_accuracy:.2f}%")
    print(f"Model saved at: {model_save_path}")
else:
    print("Training finished, but no test data was available for evaluation.")
    torch.save(model.state_dict(), model_save_path) # Save the last model if no test data
    print(f"Last model state saved to {model_save_path}")


# ==============================================================================
# Cell 8: Testing Function
# ==============================================================================

def predict_video(video_path, trained_model, device, frame_skip, sequence_length, class_index_to_name):
    """
    Processes a single video, extracts keypoints, and predicts the class using the trained model.
    (Same function as before)
    """
    print(f"\nTesting video: {video_path}")
    mp_pose_pred = mp.solutions.pose
    pose_pred = mp_pose_pred.Pose(static_image_mode=False, model_complexity=1, smooth_landmarks=True,
                                  enable_segmentation=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)

    keypoints_data = extract_keypoints_from_video(video_path, frame_skip, sequence_length)
    pose_pred.close()

    if keypoints_data is None:
        print("  -> Failed to extract features from the video.")
        return None

    sequence_tensor = torch.tensor(keypoints_data, dtype=torch.float32).unsqueeze(0).to(device)

    trained_model.eval()
    with torch.no_grad():
        outputs = trained_model(sequence_tensor)
        probabilities = torch.softmax(outputs, dim=1)
        confidence, predicted_idx = torch.max(probabilities, 1)
        predicted_class_index = predicted_idx.item()
        prediction_confidence = confidence.item()

    predicted_class_name = class_index_to_name.get(predicted_class_index, "Unknown")
    print(f"  -> Prediction: {predicted_class_name} (Confidence: {prediction_confidence:.4f})")
    return predicted_class_name


# ==============================================================================
# Cell 9: Example Usage of Testing Function
# ==============================================================================

# --- Load the saved model ---
print("\nLoading the trained model for testing...")
model_load_path = os.path.join(MODEL_SAVE_DIR, MODEL_NAME)

test_model = FallDetectionRNN(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, rnn_type='LSTM') # Ensure params match

try:
    # Load state dict considering the device
    map_location = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    test_model.load_state_dict(torch.load(model_load_path, map_location=map_location))
    test_model.to(DEVICE) # Move model to the correct device
    test_model.eval()
    print("Model loaded successfully.")
except FileNotFoundError:
    print(f"Error: Model file not found at {model_load_path}. Cannot perform testing.")
    test_model = None
except Exception as e:
    print(f"Error loading model state_dict: {e}")
    test_model = None

# --- Specify a test video ---
TEST_VIDEO_PATH = '/content/drive/MyDrive/dataset/test_data/side_fall/example_side_fall_test_video.mp4'


# --- Run prediction (if model loaded successfully) ---
if test_model is not None:
    if os.path.exists(TEST_VIDEO_PATH):
        predicted_class = predict_video(
            video_path=TEST_VIDEO_PATH,
            trained_model=test_model,
            device=DEVICE,
            frame_skip=FRAME_SKIP, 
            sequence_length=SEQUENCE_LENGTH,
            class_index_to_name=index_to_name
        )
        if predicted_class:
            print(f"\nFinal Prediction for {os.path.basename(TEST_VIDEO_PATH)}: {predicted_class}")
        else:
            print(f"\nCould not get prediction for {os.path.basename(TEST_VIDEO_PATH)}.")
    else:
         print(f"\nError: Test video file not found at {TEST_VIDEO_PATH}. Please verify the path.")
elif test_model is None:
     print("\nSkipping testing because the model could not be loaded.")

print("\n--- End of Script ---")
# Out:
# Found existing installation: numpy 2.2.4
# Uninstalling numpy-2.2.4:
#   Successfully uninstalled numpy-2.2.4
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# Found existing installation: torchvision 0.21.0
# Uninstalling torchvision-0.21.0:
#   Successfully uninstalled torchvision-0.21.0
# Found existing installation: torchaudio 2.6.0
# Uninstalling torchaudio-2.6.0:
#   Successfully uninstalled torchaudio-2.6.0
# Collecting numpy
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.9 MB/s eta 0:00:00
# Collecting torch
#   Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.13.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 331.6 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 322.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 331.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 301.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 298.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 363.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 306.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 315.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 325.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 316.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 314.3 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 320.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 324.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 322.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 319.1 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 274.1 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 319.5 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 295.3 MB/s eta 0:00:00
# Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 357.6 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 314.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 221.7 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 300.7 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 335.2 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 383.8 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 388.1 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.2.4 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.4 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-11.1.0 sympy-1.13.1 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0 triton-3.2.0 typing-extensions-4.13.0
# Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully.
# Installing libraries...
# Libraries already installed or installation not needed in this environment.
# All necessary libraries are imported.
# Using device: cpu
# Configuration loaded:
#   Base Path: /content/drive/MyDrive/dataset
#   Train Data Path: /content/drive/MyDrive/dataset/train_data
#   Test Data Path: /content/drive/MyDrive/dataset/test_data
#   Feature Path: /content/drive/MyDrive/dataset/processed_features
#   Model Save Path: /content/drive/MyDrive/dataset/trained_models
#   Classes: ['backward_fall', 'forward_fall', 'side_fall', 'non_fall']
#   Label Map: {'backward_fall': 0, 'forward_fall': 1, 'side_fall': 2, 'non_fall': 3}
#   Frame Skip: 3
#   Sequence Length: 30
#
# Starting Feature Extraction...
#
# Processing data source: /content/drive/MyDrive/dataset/train_data
#
#   Processing class: backward_fall (Label: 0)
#     Video folder: /content/drive/MyDrive/dataset/train_data/backward_fall
#     Processing 02526_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C2.pkl
#     Processing 02526_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C3.pkl
#     Processing 02526_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C4.pkl
#     Processing 02526_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C5.pkl
#     Processing 02526_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C6.pkl
#     Processing 02526_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C7.pkl
#     Processing 02526_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02526_H_A_BY_C8.pkl
#     Processing 02530_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C1.pkl
#     Processing 02530_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C2.pkl
#     Processing 02530_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C3.pkl
#     Processing 02530_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C4.pkl
#     Processing 02530_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C5.pkl
#     Processing 02530_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C6.pkl
#     Processing 02530_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C7.pkl
#     Processing 02530_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02530_H_A_BY_C8.pkl
#     Processing 02536_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C1.pkl
#     Processing 02536_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C2.pkl
#     Processing 02536_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C3.pkl
#     Processing 02536_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C4.pkl
#     Processing 02536_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C5.pkl
#     Processing 02536_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C6.pkl
#     Processing 02536_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C7.pkl
#     Processing 02536_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02536_H_D_BY_C8.pkl
#     Processing 02540_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C1.pkl
#     Processing 02540_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C2.pkl
#     Processing 02540_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C3.pkl
#     Processing 02540_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C4.pkl
#     Processing 02540_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C5.pkl
#     Processing 02540_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C6.pkl
#     Processing 02540_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C7.pkl
#     Processing 02540_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02540_H_D_BY_C8.pkl
#     Processing 02544_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C1.pkl
#     Processing 02544_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C2.pkl
#     Processing 02544_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C3.pkl
#     Processing 02544_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C4.pkl
#     Processing 02544_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C5.pkl
#     Processing 02544_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C6.pkl
#     Processing 02544_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C7.pkl
#     Processing 02544_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02544_H_D_BY_C8.pkl
#     Processing 02548_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C1.pkl
#     Processing 02548_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C2.pkl
#     Processing 02548_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C3.pkl
#     Processing 02548_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C4.pkl
#     Processing 02548_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C5.pkl
#     Processing 02548_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C6.pkl
#     Processing 02548_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C7.pkl
#     Processing 02548_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02548_H_D_BY_C8.pkl
#     Processing 02552_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C1.pkl
#     Processing 02552_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C2.pkl
#     Processing 02552_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C3.pkl
#     Processing 02552_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C4.pkl
#     Processing 02552_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C5.pkl
#     Processing 02552_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C6.pkl
#     Processing 02552_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C7.pkl
#     Processing 02552_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02552_H_D_BY_C8.pkl
#     Processing 02556_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C1.pkl
#     Processing 02556_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C2.pkl
#     Processing 02556_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C3.pkl
#     Processing 02556_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C4.pkl
#     Processing 02556_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C5.pkl
#     Processing 02556_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C6.pkl
#     Processing 02556_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C7.pkl
#     Processing 02556_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02556_H_D_BY_C8.pkl
#     Processing 02560_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C1.pkl
#     Processing 02560_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C2.pkl
#     Processing 02560_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C3.pkl
#     Processing 02560_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C4.pkl
#     Processing 02560_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C5.pkl
#     Processing 02560_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C6.pkl
#     Processing 02560_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C7.pkl
#     Processing 02560_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02560_H_D_BY_C8.pkl
#     Processing 02564_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C1.pkl
#     Processing 02564_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C2.pkl
#     Processing 02564_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C3.pkl
#     Processing 02564_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C4.pkl
#     Processing 02564_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C5.pkl
#     Processing 02564_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C6.pkl
#     Processing 02564_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C7.pkl
#     Processing 02564_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02564_H_D_BY_C8.pkl
#     Processing 02568_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C1.pkl
#     Processing 02568_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C2.pkl
#     Processing 02568_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C3.pkl
#     Processing 02568_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C4.pkl
#     Processing 02568_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C5.pkl
#     Processing 02568_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C6.pkl
#     Processing 02568_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C7.pkl
#     Processing 02568_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02568_H_D_BY_C8.pkl
#     Processing 02572_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C1.pkl
#     Processing 02572_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C2.pkl
#     Processing 02572_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C3.pkl
#     Processing 02572_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C4.pkl
#     Processing 02572_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C5.pkl
#     Processing 02572_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C6.pkl
#     Processing 02572_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C7.pkl
#     Processing 02572_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02572_H_D_BY_C8.pkl
#     Processing 02578_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C1.pkl
#     Processing 02578_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C2.pkl
#     Processing 02578_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C3.pkl
#     Processing 02578_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C4.pkl
#     Processing 02578_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C5.pkl
#     Processing 02578_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C6.pkl
#     Processing 02578_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C7.pkl
#     Processing 02578_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02578_H_D_BY_C8.pkl
#     Processing 02582_H_D_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C1.pkl
#     Processing 02582_H_D_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C2.pkl
#     Processing 02582_H_D_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C3.pkl
#     Processing 02582_H_D_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C4.pkl
#     Processing 02582_H_D_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C5.pkl
#     Processing 02582_H_D_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C6.pkl
#     Processing 02582_H_D_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C7.pkl
#     Processing 02582_H_D_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02582_H_D_BY_C8.pkl
#     Processing 02590_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C1.pkl
#     Processing 02590_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C2.pkl
#     Processing 02590_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C3.pkl
#     Processing 02590_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C4.pkl
#     Processing 02590_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C5.pkl
#     Processing 02590_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C6.pkl
#     Processing 02590_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C7.pkl
#     Processing 02590_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02590_H_A_BY_C8.pkl
#     Processing 02594_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C1.pkl
#     Processing 02594_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C2.pkl
#     Processing 02594_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C3.pkl
#     Processing 02594_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C4.pkl
#     Processing 02594_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C5.pkl
#     Processing 02594_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C6.pkl
#     Processing 02594_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C7.pkl
#     Processing 02594_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02594_H_A_BY_C8.pkl
#     Processing 02598_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C1.pkl
#     Processing 02598_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C2.pkl
#     Processing 02598_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C3.pkl
#     Processing 02598_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C4.pkl
#     Processing 02598_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C5.pkl
#     Processing 02598_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C6.pkl
#     Processing 02598_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C7.pkl
#     Processing 02598_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02598_H_A_BY_C8.pkl
#     Processing 02602_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C1.pkl
#     Processing 02602_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C2.pkl
#     Processing 02602_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C3.pkl
#     Processing 02602_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C4.pkl
#     Processing 02602_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C5.pkl
#     Processing 02602_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C6.pkl
#     Processing 02602_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C7.pkl
#     Processing 02602_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02602_H_A_BY_C8.pkl
#     Processing 02606_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C1.pkl
#     Processing 02606_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C2.pkl
#     Processing 02606_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C3.pkl
#     Processing 02606_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C4.pkl
#     Processing 02606_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C5.pkl
#     Processing 02606_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C6.pkl
#     Processing 02606_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C7.pkl
#     Processing 02606_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02606_H_A_BY_C8.pkl
#     Processing 02610_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C1.pkl
#     Processing 02610_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C2.pkl
#     Processing 02610_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C3.pkl
#     Processing 02610_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C4.pkl
#     Processing 02610_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C5.pkl
#     Processing 02610_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C6.pkl
#     Processing 02610_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C7.pkl
#     Processing 02610_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02610_H_A_BY_C8.pkl
#     Processing 02614_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C1.pkl
#     Processing 02614_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C2.pkl
#     Processing 02614_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C3.pkl
#     Processing 02614_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C4.pkl
#     Processing 02614_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C5.pkl
#     Processing 02614_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C6.pkl
#     Processing 02614_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C7.pkl
#     Processing 02614_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02614_H_A_BY_C8.pkl
#     Processing 02618_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C1.pkl
#     Processing 02618_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C2.pkl
#     Processing 02618_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C3.pkl
#     Processing 02618_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C4.pkl
#     Processing 02618_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C5.pkl
#     Processing 02618_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C6.pkl
#     Processing 02618_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C7.pkl
#     Processing 02618_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02618_H_A_BY_C8.pkl
#     Processing 02623_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C1.pkl
#     Processing 02623_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C2.pkl
#     Processing 02623_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C3.pkl
#     Processing 02623_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C4.pkl
#     Processing 02623_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C5.pkl
#     Processing 02623_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C6.pkl
#     Processing 02623_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C7.pkl
#     Processing 02623_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02623_H_A_BY_C8.pkl
#     Processing 02628_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C1.pkl
#     Processing 02628_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C2.pkl
#     Processing 02628_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C3.pkl
#     Processing 02628_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C4.pkl
#     Processing 02628_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C5.pkl
#     Processing 02628_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C6.pkl
#     Processing 02628_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C7.pkl
#     Processing 02628_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02628_H_A_BY_C8.pkl
#     Processing 02632_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C1.pkl
#     Processing 02632_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C2.pkl
#     Processing 02632_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C3.pkl
#     Processing 02632_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C4.pkl
#     Processing 02632_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C5.pkl
#     Processing 02632_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C6.pkl
#     Processing 02632_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C7.pkl
#     Processing 02632_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02632_H_A_BY_C8.pkl
#     Processing 02638_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C1.pkl
#     Processing 02638_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C2.pkl
#     Processing 02638_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C3.pkl
#     Processing 02638_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C4.pkl
#     Processing 02638_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C5.pkl
#     Processing 02638_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C6.pkl
#     Processing 02638_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C7.pkl
#     Processing 02638_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02638_H_A_BY_C8.pkl
#     Processing 02663_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C1.pkl
#     Processing 02663_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C2.pkl
#     Processing 02663_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C3.pkl
#     Processing 02663_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C4.pkl
#     Processing 02663_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C5.pkl
#     Processing 02663_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C6.pkl
#     Processing 02663_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C7.pkl
#     Processing 02663_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02663_H_A_BY_C8.pkl
#     Processing 02668_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C1.pkl
#     Processing 02668_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C2.pkl
#     Processing 02668_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C3.pkl
#     Processing 02668_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C4.pkl
#     Processing 02668_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C5.pkl
#     Processing 02668_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C6.pkl
#     Processing 02668_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C7.pkl
#     Processing 02668_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02668_H_A_BY_C8.pkl
#     Processing 02677_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C1.pkl
#     Processing 02677_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C2.pkl
#     Processing 02677_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C3.pkl
#     Processing 02677_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C4.pkl
#     Processing 02677_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C5.pkl
#     Processing 02677_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C6.pkl
#     Processing 02677_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C7.pkl
#     Processing 02677_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02677_H_A_BY_C8.pkl
#     Processing 02679_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C1.pkl
#     Processing 02679_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C2.pkl
#     Processing 02679_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C3.pkl
#     Processing 02679_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C4.pkl
#     Processing 02679_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C5.pkl
#     Processing 02679_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C6.pkl
#     Processing 02679_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C7.pkl
#     Processing 02679_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02679_H_A_BY_C8.pkl
#     Processing 02681_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C1.pkl
#     Processing 02681_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C2.pkl
#     Processing 02681_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C3.pkl
#     Processing 02681_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C4.pkl
#     Processing 02681_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C5.pkl
#     Processing 02681_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C6.pkl
#     Processing 02681_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C7.pkl
#     Processing 02681_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02681_H_A_BY_C8.pkl
#     Processing 02684_H_A_BY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C1.pkl
#     Processing 02684_H_A_BY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C2.pkl
#     Processing 02684_H_A_BY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C3.pkl
#     Processing 02684_H_A_BY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C4.pkl
#     Processing 02684_H_A_BY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C5.pkl
#     Processing 02684_H_A_BY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C6.pkl
#     Processing 02684_H_A_BY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C7.pkl
#     Processing 02684_H_A_BY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/backward_fall/02684_H_A_BY_C8.pkl
#     Processing 02686_H_A_BY_C1.mp4...
# ...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C3.pkl
#     Processing 00254_H_D_SY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C4.pkl
#     Processing 00254_H_D_SY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C5.pkl
#     Processing 00254_H_D_SY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C6.pkl
#     Processing 00254_H_D_SY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C7.pkl
#     Processing 00254_H_D_SY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00254_H_D_SY_C8.pkl
#     Processing 00258_H_D_SY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C1.pkl
#     Processing 00258_H_D_SY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C2.pkl
#     Processing 00258_H_D_SY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C3.pkl
#     Processing 00258_H_D_SY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C4.pkl
#     Processing 00258_H_D_SY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C5.pkl
#     Processing 00258_H_D_SY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C6.pkl
#     Processing 00258_H_D_SY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C7.pkl
#     Processing 00258_H_D_SY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00258_H_D_SY_C8.pkl
#     Processing 00262_H_D_SY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C1.pkl
#     Processing 00262_H_D_SY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C2.pkl
#     Processing 00262_H_D_SY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C3.pkl
#     Processing 00262_H_D_SY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C4.pkl
#     Processing 00262_H_D_SY_C5.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C5.pkl
#     Processing 00262_H_D_SY_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C6.pkl
#     Processing 00262_H_D_SY_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C7.pkl
#     Processing 00262_H_D_SY_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00262_H_D_SY_C8.pkl
#     Processing 00266_H_D_SY_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00266_H_D_SY_C1.pkl
#     Processing 00266_H_D_SY_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00266_H_D_SY_C2.pkl
#     Processing 00266_H_D_SY_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00266_H_D_SY_C3.pkl
#     Processing 00266_H_D_SY_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/side_fall/00266_H_D_SY_C4.pkl
#
#   Processing class: non_fall (Label: 3)
#     Video folder: /content/drive/MyDrive/dataset/test_data/non_fall
#     Skipping 00280_H_D_N_C6.mp4, features already exist at /content/drive/MyDrive/dataset/processed_features/non_fall/00280_H_D_N_C6.pkl
#     Processing 00280_H_D_N_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00280_H_D_N_C7.pkl
#     Processing 00284_H_A_N_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00284_H_A_N_C6.pkl
#     Processing 00284_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00284_H_A_N_C1.pkl
#     Processing 00284_H_A_N_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00284_H_A_N_C4.pkl
#     Processing 00288_H_A_N_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00288_H_A_N_C4.pkl
#     Processing 00288_H_A_N_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00288_H_A_N_C2.pkl
#     Processing 00296_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00296_H_A_N_C1.pkl
#     Processing 00296_H_A_N_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00296_H_A_N_C7.pkl
#     Processing 00296_H_A_N_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00296_H_A_N_C4.pkl
#     Processing 00306_H_A_N_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00306_H_A_N_C6.pkl
#     Processing 00306_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00306_H_A_N_C1.pkl
#     Processing 00306_H_A_N_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00306_H_A_N_C3.pkl
#     Processing 00309_H_A_N_C4.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00309_H_A_N_C4.pkl
#     Processing 00309_H_A_N_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00309_H_A_N_C2.pkl
#     Processing 00309_H_A_N_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00309_H_A_N_C8.pkl
#     Processing 00310_H_A_N_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00310_H_A_N_C3.pkl
#     Processing 00310_H_A_N_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00310_H_A_N_C6.pkl
#     Processing 00313_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00313_H_A_N_C1.pkl
#     Processing 00314_H_A_N_C8.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00314_H_A_N_C8.pkl
#     Processing 00314_H_A_N_C2.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00314_H_A_N_C2.pkl
#     Processing 00313_H_A_N_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00313_H_A_N_C7.pkl
#     Processing 00318_H_A_N_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00318_H_A_N_C3.pkl
#     Processing 00318_H_A_N_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00318_H_A_N_C6.pkl
#     Processing 00322_H_A_N_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00322_H_A_N_C3.pkl
#     Processing 00322_H_A_N_C7.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00322_H_A_N_C7.pkl
#     Processing 00322_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00322_H_A_N_C1.pkl
#     Processing 00326_H_A_N_C6.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00326_H_A_N_C6.pkl
#     Processing 00326_H_A_N_C3.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00326_H_A_N_C3.pkl
#     Processing 00330_H_A_N_C1.mp4...
#       Saved features to /content/drive/MyDrive/dataset/processed_features/non_fall/00330_H_A_N_C1.pkl
#
# Feature extraction completed in 4611.20 seconds.
# Total training feature files processed/loaded: 1697
# Total testing feature files processed/loaded: 390
# Datasets and DataLoaders created.
#   Training samples: 1697
#   Testing samples: 390
# Model Architecture:
# FallDetectionRNN(
#   (rnn): LSTM(99, 128, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=128, out_features=4, bias=True)
# )
# Total trainable parameters: 249860
# Loss function and optimizer defined.
#   Criterion: CrossEntropyLoss()
#   Optimizer: Adam (LR=0.001)
#
# Starting Training...
# Epoch [1/50] (30.89s) | Train Loss: 1.1282, Train Acc: 39.13% | Test Loss: 1.0349, Test Acc: 42.82%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 42.82%)
# Epoch [2/50] (30.30s) | Train Loss: 1.0197, Train Acc: 44.61% | Test Loss: 1.0858, Test Acc: 26.15%
# Epoch [3/50] (30.70s) | Train Loss: 0.9862, Train Acc: 47.44% | Test Loss: 1.1312, Test Acc: 38.21%
# Epoch [4/50] (30.50s) | Train Loss: 0.9816, Train Acc: 50.68% | Test Loss: 1.0425, Test Acc: 44.36%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 44.36%)
# Epoch [5/50] (30.30s) | Train Loss: 0.9810, Train Acc: 50.27% | Test Loss: 0.9738, Test Acc: 42.31%
# Epoch [6/50] (30.60s) | Train Loss: 0.9355, Train Acc: 52.09% | Test Loss: 1.0035, Test Acc: 47.18%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 47.18%)
# Epoch [7/50] (30.50s) | Train Loss: 0.9369, Train Acc: 54.15% | Test Loss: 0.9910, Test Acc: 48.72%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 48.72%)
# Epoch [8/50] (30.49s) | Train Loss: 0.8989, Train Acc: 55.45% | Test Loss: 1.0277, Test Acc: 45.64%
# Epoch [9/50] (30.30s) | Train Loss: 0.8655, Train Acc: 57.28% | Test Loss: 0.9954, Test Acc: 49.49%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 49.49%)
# Epoch [10/50] (30.50s) | Train Loss: 0.8507, Train Acc: 58.81% | Test Loss: 1.0000, Test Acc: 50.00%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 50.00%)
# Epoch [11/50] (30.49s) | Train Loss: 0.8738, Train Acc: 56.10% | Test Loss: 0.9711, Test Acc: 49.49%
# Epoch [12/50] (30.31s) | Train Loss: 0.8330, Train Acc: 58.46% | Test Loss: 0.9950, Test Acc: 51.03%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 51.03%)
# Epoch [13/50] (30.39s) | Train Loss: 0.8168, Train Acc: 60.58% | Test Loss: 1.1201, Test Acc: 44.62%
# Epoch [14/50] (30.50s) | Train Loss: 0.8356, Train Acc: 59.05% | Test Loss: 0.9752, Test Acc: 53.33%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 53.33%)
# Epoch [15/50] (30.30s) | Train Loss: 0.7554, Train Acc: 61.23% | Test Loss: 0.9665, Test Acc: 53.59%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 53.59%)
# Epoch [16/50] (30.50s) | Train Loss: 0.7673, Train Acc: 61.99% | Test Loss: 1.1297, Test Acc: 41.28%
# Epoch [17/50] (30.60s) | Train Loss: 0.7872, Train Acc: 61.11% | Test Loss: 0.9250, Test Acc: 54.87%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 54.87%)
# Epoch [18/50] (30.50s) | Train Loss: 0.6815, Train Acc: 66.41% | Test Loss: 0.9642, Test Acc: 53.08%
# Epoch [19/50] (30.60s) | Train Loss: 0.6660, Train Acc: 66.00% | Test Loss: 0.9717, Test Acc: 53.59%
# Epoch [20/50] (30.60s) | Train Loss: 0.6443, Train Acc: 68.30% | Test Loss: 0.9360, Test Acc: 56.92%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 56.92%)
# Epoch [21/50] (30.48s) | Train Loss: 0.6505, Train Acc: 67.65% | Test Loss: 1.0481, Test Acc: 53.59%
# Epoch [22/50] (30.60s) | Train Loss: 0.6565, Train Acc: 67.71% | Test Loss: 0.8536, Test Acc: 56.15%
# Epoch [23/50] (30.50s) | Train Loss: 0.6304, Train Acc: 67.30% | Test Loss: 0.9528, Test Acc: 58.46%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 58.46%)
# Epoch [24/50] (30.40s) | Train Loss: 0.5760, Train Acc: 71.71% | Test Loss: 0.8535, Test Acc: 57.44%
# Epoch [25/50] (30.70s) | Train Loss: 0.5683, Train Acc: 72.19% | Test Loss: 0.7894, Test Acc: 63.59%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 63.59%)
# Epoch [26/50] (30.40s) | Train Loss: 0.5864, Train Acc: 70.95% | Test Loss: 1.0079, Test Acc: 52.05%
# Epoch [27/50] (30.40s) | Train Loss: 0.5586, Train Acc: 72.36% | Test Loss: 0.8440, Test Acc: 60.77%
# Epoch [28/50] (30.70s) | Train Loss: 0.5772, Train Acc: 72.54% | Test Loss: 0.8471, Test Acc: 60.00%
# Epoch [29/50] (30.50s) | Train Loss: 0.5437, Train Acc: 73.36% | Test Loss: 0.9561, Test Acc: 58.21%
# Epoch [30/50] (30.70s) | Train Loss: 0.5385, Train Acc: 74.25% | Test Loss: 0.9421, Test Acc: 60.00%
# Epoch [31/50] (30.50s) | Train Loss: 0.5496, Train Acc: 74.25% | Test Loss: 0.7699, Test Acc: 63.08%
# Epoch [32/50] (30.60s) | Train Loss: 0.5491, Train Acc: 71.60% | Test Loss: 0.8480, Test Acc: 62.05%
# Epoch [33/50] (30.50s) | Train Loss: 0.5094, Train Acc: 75.66% | Test Loss: 0.7900, Test Acc: 60.26%
# Epoch [34/50] (30.60s) | Train Loss: 0.5132, Train Acc: 75.78% | Test Loss: 0.8242, Test Acc: 61.79%
# Epoch [35/50] (30.70s) | Train Loss: 0.5139, Train Acc: 72.95% | Test Loss: 0.7485, Test Acc: 64.10%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 64.10%)
# Epoch [36/50] (30.49s) | Train Loss: 0.5095, Train Acc: 77.20% | Test Loss: 0.8385, Test Acc: 63.08%
# Epoch [37/50] (30.60s) | Train Loss: 0.5005, Train Acc: 75.90% | Test Loss: 0.8050, Test Acc: 60.00%
# Epoch [38/50] (30.40s) | Train Loss: 0.4778, Train Acc: 77.73% | Test Loss: 0.8769, Test Acc: 61.28%
# Epoch [39/50] (31.20s) | Train Loss: 0.4720, Train Acc: 76.78% | Test Loss: 0.7997, Test Acc: 65.13%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 65.13%)
# Epoch [40/50] (30.50s) | Train Loss: 0.4715, Train Acc: 76.78% | Test Loss: 0.8856, Test Acc: 60.26%
# Epoch [41/50] (31.00s) | Train Loss: 0.4923, Train Acc: 77.08% | Test Loss: 0.7526, Test Acc: 66.15%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 66.15%)
# Epoch [42/50] (30.40s) | Train Loss: 0.4759, Train Acc: 78.14% | Test Loss: 0.7746, Test Acc: 64.10%
# Epoch [43/50] (30.50s) | Train Loss: 0.4440, Train Acc: 79.67% | Test Loss: 0.9030, Test Acc: 62.31%
# Epoch [44/50] (30.50s) | Train Loss: 0.5251, Train Acc: 77.08% | Test Loss: 0.9145, Test Acc: 61.03%
# Epoch [45/50] (30.50s) | Train Loss: 0.4622, Train Acc: 77.55% | Test Loss: 0.8769, Test Acc: 64.36%
# Epoch [46/50] (30.50s) | Train Loss: 0.4324, Train Acc: 80.61% | Test Loss: 0.7089, Test Acc: 66.67%
#   -> New best model saved to /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth (Test Acc: 66.67%)
# Epoch [47/50] (30.30s) | Train Loss: 0.4530, Train Acc: 79.26% | Test Loss: 0.8849, Test Acc: 62.82%
# Epoch [48/50] (30.50s) | Train Loss: 0.4252, Train Acc: 80.02% | Test Loss: 0.7797, Test Acc: 65.13%
# Epoch [49/50] (30.50s) | Train Loss: 0.4498, Train Acc: 79.91% | Test Loss: 0.8065, Test Acc: 66.41%
# Epoch [50/50] (30.59s) | Train Loss: 0.6425, Train Acc: 70.65% | Test Loss: 0.7017, Test Acc: 63.85%
#
# Training Finished.
# Best Test Accuracy achieved during training: 66.67%
# Model saved at: /content/drive/MyDrive/dataset/trained_models/fall_detection_rnn_v2.pth
#
# Loading the trained model for testing...
# Model loaded successfully.
#
# Error: Test video file not found at /content/drive/MyDrive/dataset/test_data/side_fall/example_side_fall_test_video.mp4. Please verify the path.
#
# --- End of Script ---
